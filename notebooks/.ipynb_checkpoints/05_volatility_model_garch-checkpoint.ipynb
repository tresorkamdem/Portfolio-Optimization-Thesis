# %% [markdown]
# ## Portfolio Optimization Thesis
#
# **Author:** Jean Jacques Kamdem
# **Matrikelnummer:** 548153
#
# **Topic:** Portfolio Optimization using Machine Learning and Volatility Models
#
# ---
#
# ## Description
#
# This notebook is part of a structured project investigating portfolio optimization.
#
# It focuses on:
# - Volatility modeling using GARCH (planned)
# ---

# %% [markdown]
# # Volatilitätsmodellierung (GARCH)
#
# Die Volatilität ist in Finanzmärkten nicht konstant, sondern zeitabhängig.
#
# GARCH-Modelle ermöglichen es, diese Dynamik zu modellieren.
#
# In diesem Abschnitt soll untersucht werden, wie sich eine dynamische Volatilität
# auf die Portfoliooptimierung auswirkt.

# %% [markdown]
# **Status:** Work in progress
